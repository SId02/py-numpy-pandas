# %% [markdown]
# ### Data Analysis using Python and Zomato Dataset
#
# ##### for windows
#       .venv\Scripts\activate
#        deactivate
#
# ##### Install Python libraries Like NumPy, Pandas, Matplotlib, and Seaborn
#
#       pip install numpy
#       pip install pandas
#       pip install matplotlib
#       pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataframe = pd.read_csv("data/Zomato_data.csv")
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dataframe = pd.read_csv("data/Zomato_data.csv")

# %%
dataframe
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# #### Let Convert rate column to float

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0];
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# #### Type of Restarunt

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("Type of Restarunt")
# Out:
# Text(0.5, 0, 'Type of Restarunt')

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes':grouped_data })
plt.plot(result,c="yellow",marker="o")
plt.xlabel("Type of Restaurant",c="grey",size=10)
plt.ylabel("Votes",c="grey" ,size=10)
# Out:
# Text(0, 0.5, 'Votes')

# %% [markdown]
# #### Rating received by Restaurants

# %%
plt.hist(dataframe['rate'],bins=5)
plt.title("Rating received by Restaurants")
plt.show()

# %% [markdown]
# #### Approximate Cost (for two people) in Restaurants

# %%
cost_data = dataframe['approx_cost(for two people)']
sns.countplot(x=cost_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>
